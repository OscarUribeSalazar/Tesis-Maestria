# %% [markdown]
# Paso 1: Obtener datos de la aplicación creada en DevCenter de Mercado libre Client ID and Secret Key

# %%
# https://developers.mercadolibre.com.mx/devcenter/

clientId = '7740131767656174'
secretKey = 'rpPAYZkmYrNNZHraeOPczYlmWjTwnYaJ'
redirectURI = 'https://reypi.com.br'

# %% [markdown]
# Paso 2: Autenticación y Autorización usando Postamn

# %%
# https://auth.mercadolibre.com.mx/authorization?response_type=code&client_id=7740131767656174&redirect_uri=https://reypi.com.br
code = 'TG-659b23f04b93970001e4f309-17228348'

# %% [markdown]
# Paso 3: Obtención de Access Token y Refresh Token con Postamn

# %%
{
    "access_token":"APP_USR-7740131767656174-122717-9f029afa8c0597a14fe2b62b7d44b4f5-17228348",
    "token_type":"Bearer",
    "expires_in":21600,
    "scope":"offline_access read write",
    "user_id":17228348,
    "refresh_token":"TG-65935a0fec2283000196ba40-17228348"
    }
# Out:
# {'access_token': 'APP_USR-7740131767656174-122717-9f029afa8c0597a14fe2b62b7d44b4f5-17228348',
#  'token_type': 'Bearer',
#  'expires_in': 21600,
#  'scope': 'offline_access read write',
#  'user_id': 17228348,
#  'refresh_token': 'TG-65935a0fec2283000196ba40-17228348'}

# %% [markdown]
# Paso 4: Obtención de código Python (Requests) a partir de postamn

# %%
import requests

url = "https://api.mercadolibre.com/oauth/token"

payload = 'grant_type=authorization_code&client_id=7740131767656174&client_secret=rpPAYZkmYrNNZHraeOPczYlmWjTwnYaJ&code=TG-65935a0fec2283000196ba40-17228348&redirect_uri=https%3A%2F%2Freypi.com.br'
headers = {
  'accept': 'application/json',
  'content-type': 'application/x-www-form-urlencoded'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"message":"Error validating grant. Your authorization code or refresh token may be expired or it was already used","error":"invalid_grant","status":400,"cause":[]}

# %% [markdown]
# Paso 7: Actualización de Access Token usando Refresh Token con Python

# %%
import requests

url = "https://api.mercadolibre.com/oauth/token"

payload = 'grant_type=refresh_token&client_id=7740131767656174&client_secret=rpPAYZkmYrNNZHraeOPczYlmWjTwnYaJ&refresh_token=TG-658c9e42a501830001ba2736-17228348'
headers = {
  'accept': 'application/json',
  'content-type': 'application/x-www-form-urlencoded'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"access_token":"APP_USR-7740131767656174-011208-0a485b64ba7452bde8d6003e4e75310e-17228348","token_type":"Bearer","expires_in":21600,"scope":"offline_access read write","user_id":17228348,"refresh_token":"TG-65a12a83c9bf4800017dc37e-17228348"}

# %% [markdown]
# Consulta de código para los sitios (Países)

# %%
import requests

url = "https://api.mercadolibre.com/sites"

payload = {}
headers = {
  'Authorization': 'Bearer APP_USR-7740131767656174-122718-df5dfedf0986449da3eaf4021515dcc2-17228348'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# [{"default_currency_id":"BRL","id":"MLB","name":"Brasil"},{"default_currency_id":"ARS","id":"MLA","name":"Argentina"},{"default_currency_id":"HNL","id":"MHN","name":"Honduras"},{"default_currency_id":"USD","id":"MEC","name":"Ecuador"},{"default_currency_id":"MXN","id":"MLM","name":"Mexico"},{"default_currency_id":"GTQ","id":"MGT","name":"Guatemala"},{"default_currency_id":"PYG","id":"MPY","name":"Paraguay"},{"default_currency_id":"COP","id":"MCO","name":"Colombia"},{"default_currency_id":"CRC","id":"MCR","name":"Costa Rica"},{"default_currency_id":"NIO","id":"MNI","name":"Nicaragua"},{"default_currency_id":"PEN","id":"MPE","name":"Perú"},{"default_currency_id":"CUP","id":"MCU","name":"Cuba"},{"default_currency_id":"VES","id":"MLV","name":"Venezuela"},{"default_currency_id":"DOP","id":"MRD","name":"Dominicana"},{"default_currency_id":"USD","id":"MSV","name":"El Salvador"},{"default_currency_id":"BOB","id":"MBO","name":"Bolivia"},{"default_currency_id":"UYU","id":"MLU","name":"Uruguay"
# ...

# %% [markdown]
# Código para México "MLM"

# %% [markdown]
# Consulta de categorías y sub categorías

# %%
# https://api.mercadolibre.com/sites/MLM/categories

# %%
import requests

url = "https://api.mercadolibre.com/sites/MLM/categories"

payload = {}
headers = {
  'Authorization': 'Bearer $ACCESS_TOKEN'
}

response = requests.request("GET", url, headers=headers, data=payload)
data_dic = response.json()

print(data_dic)
# Out:
# [{'id': 'MLM1747', 'name': 'Accesorios para Vehículos'}, {'id': 'MLM189530', 'name': 'Agro'}, {'id': 'MLM1403', 'name': 'Alimentos y Bebidas'}, {'id': 'MLM1071', 'name': 'Animales y Mascotas'}, {'id': 'MLM1367', 'name': 'Antigüedades y Colecciones'}, {'id': 'MLM1368', 'name': 'Arte, Papelería y Mercería'}, {'id': 'MLM1743', 'name': 'Autos, Motos y Otros'}, {'id': 'MLM1384', 'name': 'Bebés'}, {'id': 'MLM1246', 'name': 'Belleza y Cuidado Personal'}, {'id': 'MLM1039', 'name': 'Cámaras y Accesorios'}, {'id': 'MLM1051', 'name': 'Celulares y Telefonía'}, {'id': 'MLM1648', 'name': 'Computación'}, {'id': 'MLM1144', 'name': 'Consolas y Videojuegos'}, {'id': 'MLM1500', 'name': 'Construcción'}, {'id': 'MLM1276', 'name': 'Deportes y Fitness'}, {'id': 'MLM1575', 'name': 'Electrodomésticos'}, {'id': 'MLM1000', 'name': 'Electrónica, Audio y Video'}, {'id': 'MLM186863', 'name': 'Herramientas'}, {'id': 'MLM1574', 'name': 'Hogar, Muebles y Jardín'}, {'id': 'MLM1499', 'name': 'Industrias y Oficinas'}, 
# ...

# %%
for i in data_dic:
    print("ID:", i['id'])
    print("Nombre de la categoría:", i['name'])
# Out:
# ID: MLM1747
# Nombre de la categoría: Accesorios para Vehículos
# ID: MLM189530
# Nombre de la categoría: Agro
# ID: MLM1403
# Nombre de la categoría: Alimentos y Bebidas
# ID: MLM1071
# Nombre de la categoría: Animales y Mascotas
# ID: MLM1367
# Nombre de la categoría: Antigüedades y Colecciones
# ID: MLM1368
# Nombre de la categoría: Arte, Papelería y Mercería
# ID: MLM1743
# Nombre de la categoría: Autos, Motos y Otros
# ID: MLM1384
# Nombre de la categoría: Bebés
# ID: MLM1246
# Nombre de la categoría: Belleza y Cuidado Personal
# ID: MLM1039
# Nombre de la categoría: Cámaras y Accesorios
# ID: MLM1051
# Nombre de la categoría: Celulares y Telefonía
# ID: MLM1648
# Nombre de la categoría: Computación
# ID: MLM1144
# Nombre de la categoría: Consolas y Videojuegos
# ID: MLM1500
# Nombre de la categoría: Construcción
# ID: MLM1276
# Nombre de la categoría: Deportes y Fitness
# ID: MLM1575
# Nombre de la categoría: Electrodomésticos
# ID: MLM1000
# ...

# %%
print("Hay un total de", len(data_dic), "Categorías")
# Out:
# Hay un total de 31 Categorías

# %% [markdown]
# La categoría que nos interesa es:
#
# ID = "MLM1574"
#
# Nombre = "Hogar, Muebles y Jardín"

# %% [markdown]
# Dentro de esta categoría existen categorías hijas las cuales son:

# %%
import requests

url = "https://api.mercadolibre.com/categories/MLM1574"

payload = {}
headers = {
  'Authorization': 'Bearer $ACCESS_TOKEN'
}

response = requests.request("GET", url, headers=headers, data=payload)
Hogar_dic = response.json()
children_categories = Hogar_dic['children_categories']
MLM1574_children_categories = []
for i in children_categories:
  print(i['id'])
  print(i['total_items_in_this_category'])
  total =+ 1

print("Número de categorías hijas:", len(children_categories))
# Out:
# MLM1631
# 1548050
# MLM1613
# 366967
# MLM437173
# 50323
# MLM8179
# 1487648
# MLM194414
# 1218037
# MLM1582
# 630228
# MLM1621
# 682791
# MLM436380
# 442418
# MLM436414
# 166896
# MLM107711
# 298013
# MLM436246
# 456680
# MLM1902
# 191115
# Número de categorías hijas: 12

# %%
import requests

url = "https://api.mercadolibre.com/categories/MLM454689"

payload = {}
headers = {
  'Authorization': 'Bearer $ACCESS_TOKEN'
}

response = requests.request("GET", url, headers=headers, data=payload)
Hogar_dic = response.json()
print(Hogar_dic['total_items_in_this_category'])
children_categories = Hogar_dic['children_categories']
print(Hogar_dic['path_from_root'])
MLM454689_children_categories = []
for i in children_categories:
  print(i['id'])
  print(i['total_items_in_this_category'])
  total =+ 1

print("Número de categorías hijas:", len(children_categories))
# Out:
# 145
# [{'id': 'MLM1574', 'name': 'Hogar, Muebles y Jardín'}, {'id': 'MLM437173', 'name': 'Camas, Colchones y Accesorios'}, {'id': 'MLM454689', 'name': 'Colchones y Box Masajeadores'}]
# Número de categorías hijas: 0

# %%
import requests

url = "https://api.mercadolibre.com/sites/MLM/search?category=MLM151398&offset=0"

payload = {}
headers = {
  'Authorization': 'Bearer APP_USR-7740131767656174-122718-99f643e169b450ead32bcdbf11568c9e-17228348'
}

response = requests.request("GET", url, headers=headers, data=payload)
MLM454689_dic = response.json()
results = MLM454689_dic['results']
print(results)
# Out:
# [{'id': 'MLM1596885435', 'title': 'Biombo Mampara Plegable De Madera 4 Hojas 220x180 Colores ', 'condition': 'new', 'thumbnail_id': '797084-MLM72244957962_102023', 'catalog_product_id': None, 'listing_type_id': 'gold_special', 'permalink': 'https://articulo.mercadolibre.com.mx/MLM-1596885435-biombo-mampara-plegable-de-madera-4-hojas-220x180-colores-_JM', 'buying_mode': 'buy_it_now', 'site_id': 'MLM', 'category_id': 'MLM151398', 'domain_id': 'MLM-FOLDING_SCREENS', 'thumbnail': 'http://http2.mlstatic.com/D_797084-MLM72244957962_102023-I.jpg', 'currency_id': 'MXN', 'order_backend': 1, 'price': 1199, 'original_price': None, 'sale_price': None, 'available_quantity': 500, 'official_store_id': None, 'use_thumbnail_id': True, 'accepts_mercadopago': True, 'variation_filters': ['COLOR'], 'shipping': {'store_pick_up': False, 'free_shipping': False, 'logistic_type': 'custom', 'mode': 'custom', 'tags': [], 'benefits': None, 'promise': None}, 'stop_time': '2042-11-02T04:00:00.000Z', 'seller': {'id
# ...

# %%
import requests

id_producto = 'MLM1743479930'
limit = 100
offset = 0

url = f"https://api.mercadolibre.com/reviews/item/{id_producto}?limit={limit}&offset={offset}"

payload = {}
headers = {
  'Authorization': 'Bearer APP_USR-7740131767656174-010718-e8ce1b9caa5a9d3863f4548d6e31e3b2-17228348'
}

response = requests.request("GET", url, headers=headers, data=payload)

data = response.json()

# %%
import pandas as pd
import requests

id_producto = 'MLM1743479930'
limit = 100
offset = 0

url = f"https://api.mercadolibre.com/reviews/item/{id_producto}?limit={limit}&offset={offset}"

payload = {}
headers = {
  'Authorization': 'Bearer APP_USR-7740131767656174-010800-9c309cde5a32da1242242dc03292e9d9-17228348'
}

response = requests.get("GET", url, headers=headers, data=payload, timeout=10)

data = response.json()

info_producto = []

num_reseñas = data['paging']['total']
promedio_reseñas = data['rating_average']
num_reseñas_calificacion = data['rating_levels']
one = num_reseñas_calificacion['one_star']
dos = num_reseñas_calificacion['two_star']
tres = num_reseñas_calificacion['three_star']
cuatro = cero = num_reseñas_calificacion['four_star']
cinco = cero = num_reseñas_calificacion['five_star']

#Agregar los datos al Dataframe
producto_info = {
    "ID": id_producto,
    'Número_Reseñas': num_reseñas,
    'Promedio_Calificación': promedio_reseñas,
    'Num_Reseñas_1': one,
    'Num_Reseñas_2': dos,
    'Num_Reseñas_3': tres,
    'Num_Reseñas_4': cuatro,
    'Num_Reseñas_5': cinco,
}

atributos = data.get('quanti_attributes', [])
atributos_dic = {}
for i in range(len(atributos)):
    Qualidad = atributos[i] 
    nombre = Qualidad['name']
    rating = Qualidad['average_rating']
    atributos_dic[f"Atributo {i + 1}"] = nombre
    atributos_dic[f"Raiting_Promedio {i + 1}"] = rating

# Agregar cada característica y calificación como columnas separadas en product_info
for key, value in atributos_dic.items():
    producto_info[key] = value

# Agregar el diccionario de info del producto a la lista
info_producto.append(producto_info)

# Crear un DataFrame a partir de la lista de reseñas
info_producto_df= pd.DataFrame(info_producto)

# Guardar los datos en un archivo CSV
info_producto_df.to_csv('Info Reseña Producto', index=False)
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[19], line 15
#      10 payload = {}
#      11 headers = {
#      12   'Authorization': 'Bearer APP_USR-7740131767656174-010800-9c309cde5a32da1242242dc03292e9d9-17228348'
#      13 }
# ---> 15 response = requests.get("GET", url, headers=headers, data=payload, timeout=10)
#      17 data = response.json()
#      19 info_producto = []
#
# File c:\Users\el_da\anaconda3\envs\Extractordereseas\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# ...

# %%
info_producto_df
# Out:
#               ID  Número_Reseñas  Promedio_Calificación  Num_Reseñas_1  \
# 0  MLM1743479930             833                    4.7             15
#
#    Num_Reseñas_2  Num_Reseñas_3  Num_Reseñas_4  Num_Reseñas_5    Atributo 1  \
# 0              7             41             98            672  cost-benefit
#
#    Raiting_Promedio 1       Atributo 2  Raiting_Promedio 2  Atributo 3  \
# 0            4.649087  display_quality            4.536885  resistance
#
#    Raiting_Promedio 3
# 0            4.327835

# %%
import pandas as pd
import requests

id_producto = 'MLM1743479930'
limit = 100

info_reseña = []

for j in range(0, num_reseñas, 100):
    offset_2 = j
    url = f"https://api.mercadolibre.com/reviews/item/{id_producto}?limit={limit}&offset={offset_2}"
    response = requests.request("GET", url, headers=headers, data=payload, timeout=10)
    data = response.json()
    num_reseñas_revisar = len(data['reviews'])

    if num_reseñas_revisar == 0:
        break  # Rompe el bucle si no hay más reseñas

    for i in range(num_reseñas_revisar):
        reseña = data['reviews'][i]
        id = reseña['id']
        fecha_creacion = reseña['date_created']
        contenido = reseña['content']
        valoracion = reseña['rate']
        rate = reseña['valorization']
        likes = reseña['likes']
        dislikes = reseña['dislikes']
        fecha_compra = reseña['buying_date']
        num_palabras = reseña['relevance']
        palabras_prohibidas = reseña['forbidden_words']
        atributos = reseña['attributes']
        media = len(reseña['media'])
        reacciones = reseña['reactions']
        variacion_atributos = reseña['attributes_variation']

        #Agregar los datos al Dataframe
        info_reseña.append({
            "ID": id_producto,
            'Fecha_Creacion': fecha_creacion,
            'Contenido': contenido,
            'Calificacion': rate,
            'Valoracion': valoracion,
            'likes': likes,
            'dislikes': dislikes,
            'fecha_compra': fecha_compra,
            'Numero de Palabras': num_palabras,
            'Palabras_Prohibidas': palabras_prohibidas,
            'Imagenes': media,
            'Reacciones': reacciones,
            'atributos': atributos,
            'Variación_Atributos': variacion_atributos
        })  

# Crear un DataFrame a partir de la lista de reseñas
info_reseña_df = pd.DataFrame(info_reseña)

# Guardar los datos en un archivo CSV
info_reseña_df.to_csv('Reseñas', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 9
#       5 limit = 100
#       7 info_reseña = []
# ----> 9 for j in range(0, num_reseñas, 100):
#      10     offset_2 = j
#      11     url = f"https://api.mercadolibre.com/reviews/item/{id_producto}?limit={limit}&offset={offset_2}"
#
# NameError: name 'num_reseñas' is not defined

# %%
import requests
import pandas as pd

id_categoria = 'MLM455214'
limit = 50

url = f"https://api.mercadolibre.com/sites/MLM/search?limit={limit}&category={id_categoria}&offset=0"

payload = {}
headers = {
    'Authorization': 'Bearer APP_USR-7740131767656174-010900-c9427735e864d21c5477524480484929-17228348'
}

response = requests.request("GET", url, headers=headers, data=payload, timeout=50)
data = response.json()
resultados = len(data['results'])
num_resultados = data['paging']['total']

info_categoria = []

for j in range(0, num_resultados, 50):
    offset_3 = j
    url = f"https://api.mercadolibre.com/sites/MLM/search?limit={limit}&category={id_categoria}&offset={offset_3}"
    response = requests.request("GET", url, headers=headers, data=payload, timeout=50)
    data = response.json()
    resultados = len(data['results'])
    if resultados == 0:
        break  # Rompe el bucle si no hay más reseñas

    for i in range(resultados):
        elemento = data['results'][i]
        id = elemento['id']

        #Agregar los datos al Dataframe
        info_categoria.append({
            "ID": id,
        })  

# Crear un DataFrame a partir de la lista de reseñas
categoria_df = pd.DataFrame(info_categoria)

# Guardar los datos en un archivo CSV
categoria_df.to_csv('Reseñas', index=False)
# Out:
# Intento 1 fallido. Razón: HTTPSConnectionPool(host='api.mercadolibre.com', port=443): Max retries exceeded with url: /sites/MLM/search?limit=50&category=MLM188288&offset=150 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000002429F30C1F0>, 'Connection to api.mercadolibre.com timed out. (connect timeout=10)'))
# Reintentando en 5 segundos...
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\el_da\anaconda3\envs\Extractordereseas\lib\site-packages\urllib3\connection.py:203, in HTTPConnection._new_conn(self)
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#
# ...

# %%
categoria_df
# Out:
#                 ID
# 0    MLM2594989722
# 1    MLM2594989722
# 2    MLM2594989722
# 3    MLM2594989722
# 4    MLM2594989722
# ..             ...
# 993  MLM1988501897
# 994  MLM1988501897
# 995  MLM1988501897
# 996  MLM1988501897
# 997  MLM1988501897
#
# [998 rows x 1 columns]

# %%
info_reseña_df.head()
# Out:
#               ID        Fecha_Creacion  \
# 0  MLM1743479930  2023-07-07T03:20:30Z
# 1  MLM1743479930  2023-05-21T21:40:49Z
# 2  MLM1743479930  2023-05-01T19:44:03Z
# 3  MLM1743479930  2023-10-05T10:03:18Z
# 4  MLM1743479930  2023-09-11T05:32:04Z
#
#                                            Contenido  Calificacion  \
# 0  Están muy padres, excelentes para los niños qu...             4
# 1  Super entretenido, muy original producto, una ...             3
# 2  Regular, por el precio puedes esperar algo así...             2
# 3  Muy bueno, puede ser muy útil e interactivo pa...             1
# 4  Mi bebé la trae para todos lados la ha pisado ...             1
#
#    Valoracion  likes  dislikes          fecha_compra  Numero de Palabras  \
# 0           5      4         0  2023-07-04T19:33:59Z                  12
# 1           5      3         0  2023-05-07T01:27:24Z                  15
# 2           4      2         0  2023-04-29T02:14:51Z                  25
# ...

# %%
import pandas as pd
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By



id_producto = 'MLM1910972743'

url = f"https://api.mercadolibre.com/items/{id_producto}"

payload = {}
headers = {
  'Authorization': 'Bearer APP_USR-7740131767656174-010821-eab99380c4875312581bc39a2e89ba6d-17228348'
}

response1 = requests.request("GET", url, headers=headers, data=payload, timeout=10)

data = response1.json()

url = f"https://api.mercadolibre.com/items/{id_producto}/description"

payload = {}
headers = {
  'Authorization': 'Bearer $ACCESS_TOKEN'
}

response2 = requests.request("GET", url, headers=headers, data=payload)
descripcion_json = response2.json()
descripcion = descripcion_json['plain_text']

info_producto = []

id = data['id']
title = data['title']
seller_id = data['seller_id']
precio = data['price']
inventario_inicial = data['initial_quantity']
link = data['permalink']
fecha_creacion = data['date_created']
ultima_actializacion = data['last_updated']
atributos = data['attributes']
categoria = data['category_id']
lista_atributos = []
for i in range(len(atributos)):
    atributo = atributos[i]
    name = atributo['name']
    value_name = atributo['value_name']
    lista_atributos.append({"":[name, value_name]})
salud = data['health']

# Inicializar el navegador
driver = webdriver.Chrome()

# Abrir la página web de busqeuda
driver.get(link)

elemento = driver.find_element(By.CLASS_NAME, 'ui-pdp-buybox__quantity__available')
elemento_texto = elemento.text

# Cerrar el controlador de Selenium
driver.quit()

elemento_split = elemento_texto.split()
inventario = int(elemento_split[0][1:])
ventas = inventario_inicial - inventario

# #Agregar los datos al Dataframe
info_producto.append({
    "ID": id,
    'Titulo': title,
    'ID_Seller': seller_id,
    'Precio': precio,
    'Inventario_Inicial': inventario_inicial,
    'link': link,
    'Fecha de Creacion': fecha_creacion,
    'Ultima_Actualizacion': ultima_actializacion,
    'Salud': salud,
    'Categoria': categoria,
    'Inventario': inventario,
    'Ventas': ventas,
    'Atributos': lista_atributos,
    'Descripción': descripcion
})  

# Crear un DataFrame a partir de la lista de reseñas
info_producto_df = pd.DataFrame(info_producto)

# Guardar los datos en un archivo CSV
info_producto_df.to_csv('Reseñas', index=False)

# %%
info_producto_df
# Out:
#               ID                                             Titulo  \
# 0  MLM1910972743  Dinosaurios Pista Carreras Juguetes Para Niños...
#
#     ID_Seller  Precio  Inventario_Inicial  \
# 0  1345145652   699.3                 825
#
#                                                 link  \
# 0  https://articulo.mercadolibre.com.mx/MLM-19109...
#
#           Fecha de Creacion      Ultima_Actualizacion  Salud  Categoria  \
# 0  2023-06-28T10:54:42.000Z  2024-01-08T09:58:51.000Z   0.87  MLM431103
#
#    Inventario  Ventas                                          Atributos  \
# 0          78     747  [{'': ['Accesorios incluidos', 'Coches de jugu...
#
#                                          Descripción
# 0  Cinco puntos de venta\nRicos accesorios:Nuestr...
